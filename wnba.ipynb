# %% [markdown]
# <a href="https://colab.research.google.com/github/patience275/wnba/blob/main/wnba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns',None)
df=pd.read_csv('/content/drive/MyDrive/dataaaaa/advanced_wnba_2023.csv')
df.head()
# Out:
#     Rk            Player   Age Team Pos     G    GS      MP   PER    TS%  \
# 0  1.0     DeMar DeRozan  34.0  CHI  SF  79.0  79.0  2989.0  19.7  0.584
# 1  2.0  Domantas Sabonis  27.0  SAC   C  82.0  82.0  2928.0  23.2  0.637
# 2  3.0        Coby White  23.0  CHI  PG  79.0  78.0  2881.0  14.5  0.570
# 3  4.0     Mikal Bridges  27.0  BRK  SF  82.0  82.0  2854.0  14.9  0.560
# 4  5.0    Paolo Banchero  21.0  ORL  PF  80.0  80.0  2799.0  17.3  0.546
#
#     3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  OWS  DWS  \
# 0  0.166  0.452   1.6  11.3   6.4  21.8   1.5   1.5   7.7  25.8  7.0  2.2
# 1  0.081  0.389  11.0  32.3  21.4  33.9   1.2   1.5  17.9  22.2  8.6  4.0
# 2  0.460  0.215   1.7  12.4   6.9  20.8   0.9   0.6  11.1  22.7  3.1  1.6
# 3  0.457  0.245   2.5  12.0   7.1  16.3   1.4   0.9  10.3  24.3  2.1  2.1
# 4  0.249  0.397   3.4  20.0  11.6  25.2   1.3   1.6  13.0  29.7  1.3  4.0
#
#      WS  WS/48  OBPM  DBPM  BPM  VORP            Awards Player-additional
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rk                 735 non-null    float64
#  1   Player             736 non-null    object
#  2   Age                735 non-null    float64
#  3   Team               735 non-null    object
#  4   Pos                735 non-null    object
#  5   G                  735 non-null    float64
#  6   GS                 735 non-null    float64
#  7   MP                 735 non-null    float64
#  8   PER                735 non-null    float64
#  9   TS%                728 non-null    float64
#  10  3PAr               728 non-null    float64
#  11  FTr                728 non-null    float64
#  12  ORB%               736 non-null    float64
#  13  DRB%               736 non-null    float64
#  14  TRB%               736 non-null    float64
# ...

# %% [markdown]
# ## rk

# %%
df['Rk'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: Rk
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %% [markdown]
# ## age

# %%
df['Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
df['Age'].unique()
# Out:
# array([34., 27., 23., 21., 35., 22., 28., 30., 29., 26., 25., 24., 33.,
#        31., 39., 20., 32., 36., 19., 37., 38., nan])

# %%
df['Age']=pd.to_numeric(df['Age'],errors='coerce')
age_mode=df['Age'].mode()[0]
df['Age']=df['Age'].fillna(age_mode)

# %%
df['Age'].unique()
# Out:
# array([34., 27., 23., 21., 35., 22., 28., 30., 29., 26., 25., 24., 33.,
#        31., 39., 20., 32., 36., 19., 37., 38.])

# %%
df['Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
age_count=df['Age'].value_counts()
age_count
# Out:
# Age
# 24.0    95
# 25.0    82
# 23.0    72
# 26.0    57
# 22.0    56
# 21.0    48
# 27.0    45
# 28.0    36
# 31.0    35
# 29.0    34
# 20.0    33
# 30.0    31
# 35.0    27
# 32.0    22
# 33.0    19
# 34.0    12
# 19.0    12
# 38.0     7
# 37.0     7
# 36.0     5
# 39.0     1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.bar(age_count.index,age_count.values)
plt.xlabel('age')
plt.ylabel('age count')
plt.title('age distribution')
plt.grid(True)
plt.show()

# %% [markdown]
# ## team

# %%
df['Team'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: Team
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    object
# dtypes: object(1)
# memory usage: 5.9+ KB

# %%
df['Team'].unique()
# Out:
# array(['CHI', 'SAC', 'BRK', 'ORL', 'PHO', 'ATL', 'MIN', 'DEN', 'NYK',
#        'LAL', 'HOU', '2TM', 'TOR', 'IND', 'BOS', 'PHI', 'DAL', 'CHO',
#        'MIL', 'OKC', 'LAC', 'CLE', 'GSW', 'MIA', 'WAS', 'NOP', 'SAS',
#        'DET', 'MEM', 'UTA', 'POR', '3TM', nan], dtype=object)

# %%
team_mode=df['Team'].mode()[0]
df['Team']=df['Team'].fillna(team_mode)

# %%
df['Team'].unique()
# Out:
# array(['CHI', 'SAC', 'BRK', 'ORL', 'PHO', 'ATL', 'MIN', 'DEN', 'NYK',
#        'LAL', 'HOU', '2TM', 'TOR', 'IND', 'BOS', 'PHI', 'DAL', 'CHO',
#        'MIL', 'OKC', 'LAC', 'CLE', 'GSW', 'MIA', 'WAS', 'NOP', 'SAS',
#        'DET', 'MEM', 'UTA', 'POR', '3TM'], dtype=object)

# %%
team_counts=df['Team'].value_counts()
team_counts
# Out:
# Team
# 2TM    72
# MEM    33
# DET    31
# TOR    30
# PHI    28
# CHO    26
# NYK    26
# WAS    24
# PHO    22
# OKC    22
# DAL    22
# POR    22
# IND    22
# MIL    21
# LAL    21
# BRK    21
# UTA    21
# LAC    21
# MIA    21
# NOP    20
# SAS    20
# SAC    20
# ATL    19
# BOS    19
# MIN    19
# CLE    18
# ORL    18
# CHI    18
# GSW    18
# DEN    17
# HOU    17
# 3TM     7
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.bar(team_counts.index,team_counts.values)
plt.xlabel('Team')
plt.ylabel('Team Count')
plt.title('Team Distribution')
plt.grid(True)
plt.xticks(rotation=90) # Rotate x-axis labels for better readability
plt.show()

# %%
plt.figure(figsize=(15, 8))
df.boxplot(column='Age', by='Team', figsize=(15, 8))
plt.title('Distribution of Age by Team')
plt.xlabel('Team')
plt.ylabel('Age')
plt.xticks(rotation=90)
plt.suptitle('') # Suppress the default title created by boxplot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## position

# %%
df['Pos'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: Pos
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    object
# dtypes: object(1)
# memory usage: 5.9+ KB

# %%
df['Pos'].unique()
# Out:
# array(['SF', 'C', 'PG', 'PF', 'SG', nan], dtype=object)

# %%
pos_mode=df['Pos'].mode()[0]
df['Pos']=df['Pos'].fillna(pos_mode)

# %%
df['Pos'].unique()
# Out:
# array(['SF', 'C', 'PG', 'PF', 'SG'], dtype=object)

# %%
pos_count=df['Pos'].value_counts()
pos_count
# Out:
# Pos
# SG    161
# SF    157
# PF    153
# PG    146
# C     119
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.bar(pos_count.index, pos_count.values)
plt.xlabel('Position')
plt.ylabel('Count')
plt.title('Position Distribution')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
df.boxplot(column='Age', by='Pos', figsize=(10, 6))
plt.title('Distribution of Age by Position')
plt.xlabel('Position')
plt.ylabel('Age')
plt.suptitle('') # Suppress the default title created by boxplot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## games

# %%
df['G'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: G
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
df['G'].unique()
# Out:
# array([79., 82., 80., 75., 78., 77., 81., 76., 73., 74., 39., 41., 70.,
#        69., 71., 51., 29., 72., 68., 44., 84., 52., 32., 66., 48., 28.,
#        47., 64., 60., 62., 63., 61., 30., 31., 58., 38., 49., 55., 54.,
#        57., 56., 67., 33., 34., 59., 26., 45., 53., 50., 65., 27., 23.,
#        37., 16., 46., 25.,  3., 42., 43., 17., 40., 24.,  6.,  1., 13.,
#        20., 18., 14., 22., 12., 35., 10.,  2.,  4., 15., 36.,  8., 19.,
#        21.,  5.,  9., 11.,  7., nan])

# %%
g_mode=df['G'].mode()[0]
df['G']=df['G'].fillna(g_mode)
df['G'].info()
df['G'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: G
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([79., 82., 80., 75., 78., 77., 81., 76., 73., 74., 39., 41., 70.,
#        69., 71., 51., 29., 72., 68., 44., 84., 52., 32., 66., 48., 28.,
#        47., 64., 60., 62., 63., 61., 30., 31., 58., 38., 49., 55., 54.,
#        57., 56., 67., 33., 34., 59., 26., 45., 53., 50., 65., 27., 23.,
#        37., 16., 46., 25.,  3., 42., 43., 17., 40., 24.,  6.,  1., 13.,
#        20., 18., 14., 22., 12., 35., 10.,  2.,  4., 15., 36.,  8., 19.,
#        21.,  5.,  9., 11.,  7.])

# %%
g_count=df['G'].value_counts()
g_count
# Out:
# G
# 6.0     19
# 68.0    18
# 82.0    16
# 2.0     16
# 3.0     16
#         ..
# 53.0     4
# 36.0     4
# 52.0     3
# 35.0     2
# 84.0     1
# Name: count, Length: 83, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.bar(g_count.index,g_count.values)
plt.xlabel('games played')
plt.ylabel('games count')
plt.title('games distribution')
plt.grid(True)
plt.show()

# %% [markdown]
# ## games started

# %%
df['GS'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: GS
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
df['GS'].unique()
# Out:
# array([79., 82., 78., 80., 75., 77., 42., 76., 73., 74., 39., 41., 57.,
#        70., 67., 81., 71., 58., 33., 25., 69., 72., 68., 63., 66., 62.,
#        45., 17., 28., 61., 37., 14., 52., 48.,  4., 43., 10., 12., 20.,
#        49., 64., 60., 51., 22., 30., 27., 44., 47.,  3., 38.,  0.,  6.,
#         8., 46., 55., 54., 56., 59., 36., 24., 11., 26., 32.,  5., 23.,
#        21., 53., 19., 13., 15., 50., 35., 34.,  9., 18., 29.,  1., 40.,
#        16.,  2., 31.,  7., nan])

# %%
df['GS']=pd.to_numeric(df['GS'],errors='coerce')
gs_mode=df['GS'].mode()[0]
df['GS']=df['GS'].fillna(gs_mean)

# %%
df['GS'].unique()
# Out:
# array([79.        , 82.        , 78.        , 80.        , 75.        ,
#        77.        , 42.        , 76.        , 73.        , 74.        ,
#        39.        , 41.        , 57.        , 70.        , 67.        ,
#        81.        , 71.        , 58.        , 33.        , 25.        ,
#        69.        , 72.        , 68.        , 63.        , 66.        ,
#        62.        , 45.        , 17.        , 28.        , 61.        ,
#        37.        , 14.        , 52.        , 48.        ,  4.        ,
#        43.        , 10.        , 12.        , 20.        , 49.        ,
#        64.        , 60.        , 51.        , 22.        , 30.        ,
#        27.        , 44.        , 47.        ,  3.        , 38.        ,
#         0.        ,  6.        ,  8.        , 46.        , 55.        ,
#        54.        , 56.        , 59.        , 36.        , 24.        ,
#        11.        , 26.        , 32.        ,  5.        , 23.        ,
# ...

# %%
gs=df['GS'].value_counts()
gs
# Out:
# GS
# 0.000000     253
# 1.000000      49
# 2.000000      24
# 3.000000      20
# 5.000000      18
#             ...
# 56.000000      1
# 34.000000      1
# 40.000000      1
# 31.000000      1
# 18.440816      1
# Name: count, Length: 83, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.bar(gs.index, gs.values)
plt.yscale('log')
plt.xlabel('Games Started (GS)')
plt.ylabel('Count')
plt.title('Distribution of Games Started')
plt.grid(True)
plt.show()

# %% [markdown]
# ## minutes played

# %%
df['MP'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: MP
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
df['MP'].unique()
# Out:
# array([2.989e+03, 2.928e+03, 2.881e+03, 2.854e+03, 2.799e+03, 2.791e+03,
#        2.783e+03, 2.770e+03, 2.737e+03, 2.726e+03, 2.707e+03, 2.700e+03,
#        2.684e+03, 2.659e+03, 2.657e+03, 1.354e+03, 1.303e+03, 2.645e+03,
#        2.629e+03, 2.626e+03, 2.624e+03, 2.610e+03, 2.601e+03, 2.593e+03,
#        2.588e+03, 2.581e+03, 2.579e+03, 2.567e+03, 2.565e+03, 2.553e+03,
#        2.513e+03, 2.504e+03, 2.502e+03, 2.486e+03, 1.559e+03, 9.270e+02,
#        2.484e+03, 2.470e+03, 2.447e+03, 2.442e+03, 2.424e+03, 2.421e+03,
#        2.416e+03, 2.413e+03, 2.411e+03, 2.402e+03, 2.401e+03, 2.383e+03,
#        2.381e+03, 2.368e+03, 2.360e+03, 2.346e+03, 2.343e+03, 2.337e+03,
#        2.330e+03, 2.321e+03, 2.297e+03, 2.284e+03, 2.281e+03, 2.263e+03,
#        2.257e+03, 2.248e+03, 2.246e+03, 2.239e+03, 2.227e+03, 2.224e+03,
#        2.223e+03, 2.221e+03, 1.286e+03, 9.350e+02, 2.217e+03, 2.212e+03,
#        2.207e+03, 2.193e+03, 2.160e+03, 1.336e+03, 8.240e+02, 2.159e+03,
# ...

# %%
df['MP']=pd.to_numeric(df['MP'],errors='coerce')
mp_mean = df['MP'].mean()
df['MP'] = df['MP'].fillna(mp_mean)
df['MP'].info()
df['MP'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: MP
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([2.98900000e+03, 2.92800000e+03, 2.88100000e+03, 2.85400000e+03,
#        2.79900000e+03, 2.79100000e+03, 2.78300000e+03, 2.77000000e+03,
#        2.73700000e+03, 2.72600000e+03, 2.70700000e+03, 2.70000000e+03,
#        2.68400000e+03, 2.65900000e+03, 2.65700000e+03, 1.35400000e+03,
#        1.30300000e+03, 2.64500000e+03, 2.62900000e+03, 2.62600000e+03,
#        2.62400000e+03, 2.61000000e+03, 2.60100000e+03, 2.59300000e+03,
#        2.58800000e+03, 2.58100000e+03, 2.57900000e+03, 2.56700000e+03,
#        2.56500000e+03, 2.55300000e+03, 2.51300000e+03, 2.50400000e+03,
#        2.50200000e+03, 2.48600000e+03, 1.55900000e+03, 9.27000000e+02,
#        2.48400000e+03, 2.47000000e+03, 2.44700000e+03, 2.44200000e+03,
# ...

# %%
mp=df['MP'].value_counts()
mp
# Out:
# MP
# 3.0       5
# 119.0     4
# 81.0      4
# 60.0      4
# 91.0      4
#          ..
# 1443.0    1
# 1436.0    1
# 1423.0    1
# 1415.0    1
# 1462.0    1
# Name: count, Length: 606, dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['MP'], bins=30, edgecolor='black')  # Using a histogram for continuous data
plt.xlabel('Minutes Played (MP)')
plt.ylabel('Frequency')
plt.title('Distribution of Minutes Played')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(df['MP'])
plt.title('Distribution of Minutes Played')
plt.ylabel('Minutes Played')
plt.xticks([]) # Remove x-axis tick labels
plt.grid(True)
plt.show()

# %% [markdown]
# ## per

# %%
df['PER'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: PER
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
df['PER'].unique()
# Out:
# array([ 19.7,  23.2,  14.5,  14.9,  17.3,  21.2,  17.7,  31. ,  23.4,
#         11.8,  25.8,  16.7,  20.1,  18.8,  20.7,  22.3,  15.5,  19.8,
#         28.1,  14.7,  19.3,  13.3,  15.4,  19.6,  29.9,  29.3,  13.8,
#         23.7,  13.9,  12.3,  16. ,  18.6,  21.9,  21.8,  20.6,  20.4,
#         14.8,  10.7,  13. ,  11.9,  16.9,  16.5,  12.1,  10.3,  17.6,
#         13.2,  16.8,  15.7,  14.4,  11.1,  11.7,   9.4,  23.3,  19.1,
#         12.2,  11. ,  12.4,  13.4,  22.8,  15.8,  11.4,  13.1,  13.6,
#         17.9,  13.5,   8. ,  10.6,   8.3,  17.4,  18.7,  12.9,   8.8,
#         23.1,  18.2,  19.5,  19.9,  16.1,  17.1,  12.8,  22. ,  19.2,
#         15.1,  14.2,  14.1,  10.4,  16.6,  17.5,  12. ,  14.6,  17. ,
#         22.1,  20.3,  10.1,  10.9,  12.7,  18.9,  10.8,  16.3,  11.6,
#         16.4,  14.3,  17.8,   9.9,  15. ,  15.3,  21.5,  21.7,  25. ,
#          9.5,   8.9,  12.6,  11.3,   9.6,  11.2,   7.7,   8.1,   7.1,
# ...

# %%
df['PER'] = pd.to_numeric(df['PER'], errors='coerce')
per_mean = df['PER'].mean()
df['PER'] = df['PER'].fillna(per_mean)
df['PER'].info()
df['PER'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: PER
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ 19.7       ,  23.2       ,  14.5       ,  14.9       ,
#         17.3       ,  21.2       ,  17.7       ,  31.        ,
#         23.4       ,  11.8       ,  25.8       ,  16.7       ,
#         20.1       ,  18.8       ,  20.7       ,  22.3       ,
#         15.5       ,  19.8       ,  28.1       ,  14.7       ,
#         19.3       ,  13.3       ,  15.4       ,  19.6       ,
#         29.9       ,  29.3       ,  13.8       ,  23.7       ,
#         13.9       ,  12.3       ,  16.        ,  18.6       ,
#         21.9       ,  21.8       ,  20.6       ,  20.4       ,
#         14.8       ,  10.7       ,  13.        ,  11.9       ,
#         16.9       ,  16.5       ,  12.1       ,  10.3       ,
#         17.6       ,  13.2       ,  16.8       ,  15.7       ,
# ...

# %%
per_count=df['PER'].value_counts()
per_count
# Out:
# PER
#  14.500000    13
#  12.800000    12
#  8.900000     12
#  13.900000    11
#  9.900000     10
#               ..
# -1.100000      1
#  26.600000     1
# -12.600000     1
# -19.300000     1
#  12.378912     1
# Name: count, Length: 234, dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['PER'], bins=30, edgecolor='black')  # Using a histogram for continuous data
plt.xlabel('Player Efficiency Rating (PER)')
plt.ylabel('Frequency')
plt.title('Distribution of PER')
plt.grid(True)
plt.show()

# %% [markdown]
# ## ts%

# %%
df['TS%'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: TS%
# Non-Null Count  Dtype
# --------------  -----
# 728 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
df['TS%'].unique()
# Out:
# array([0.584, 0.637, 0.57 , 0.56 , 0.546, 0.626, 0.555, 0.575, 0.65 ,
#        0.592, 0.522, 0.621, 0.568, 0.567, 0.601, 0.6  , 0.602, 0.604,
#        0.613, 0.573, 0.617, 0.54 , 0.541, 0.675, 0.569, 0.556, 0.59 ,
#        0.649, 0.636, 0.679, 0.63 , 0.55 , 0.559, 0.535, 0.588, 0.612,
#        0.611, 0.664, 0.571, 0.616, 0.576, 0.632, 0.608, 0.552, 0.597,
#        0.529, 0.58 , 0.603, 0.607, 0.547, 0.578, 0.593, 0.553, 0.549,
#        0.605, 0.537, 0.545, 0.536, 0.61 , 0.627, 0.513, 0.586, 0.566,
#        0.543, 0.53 , 0.591, 0.618, 0.542, 0.629, 0.574, 0.579, 0.565,
#        0.554, 0.62 , 0.585, 0.531, 0.625, 0.533, 0.581, 0.631, 0.548,
#        0.577, 0.598, 0.564, 0.595, 0.524, 0.544, 0.619, 0.67 , 0.599,
#        0.615, 0.563, 0.557, 0.583, 0.628, 0.521, 0.731, 0.707, 0.769,
#        0.671, 0.587, 0.653, 0.489, 0.717, 0.661, 0.677, 0.644, 0.647,
#        0.594, 0.582, 0.497, 0.453, 0.512, 0.539, 0.526, 0.562, 0.514,
# ...

# %%
df['TS%'] = pd.to_numeric(df['TS%'], errors='coerce')
ts_mean = df['TS%'].mean()
df['TS%'] = df['TS%'].fillna(ts_mean)
df['TS%'].info()
df['TS%'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: TS%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([0.584     , 0.637     , 0.57      , 0.56      , 0.546     ,
#        0.626     , 0.555     , 0.575     , 0.65      , 0.592     ,
#        0.522     , 0.621     , 0.568     , 0.567     , 0.601     ,
#        0.6       , 0.602     , 0.604     , 0.613     , 0.573     ,
#        0.617     , 0.54      , 0.541     , 0.675     , 0.569     ,
#        0.556     , 0.59      , 0.649     , 0.636     , 0.679     ,
#        0.63      , 0.55      , 0.559     , 0.535     , 0.588     ,
#        0.612     , 0.611     , 0.664     , 0.571     , 0.616     ,
#        0.576     , 0.632     , 0.608     , 0.552     , 0.597     ,
#        0.529     , 0.58      , 0.603     , 0.607     , 0.547     ,
#        0.578     , 0.593     , 0.553     , 0.549     , 0.605     ,
# ...

# %%
ts_counts=df['TS%'].value_counts()
ts_counts
# Out:
# TS%
# 0.597    10
# 0.578    10
# 0.560     9
# 0.576     9
# 0.537     9
#          ..
# 0.292     1
# 0.373     1
# 0.296     1
# 0.833     1
# 0.214     1
# Name: count, Length: 282, dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['TS%'], bins=30, edgecolor='black')  # Using a histogram for continuous data
plt.xlabel('True Shooting Percentage (TS%)')
plt.ylabel('Frequency')
plt.title('Distribution of TS%')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 3par

# %%
df['3PAr'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: 3PAr
# Non-Null Count  Dtype
# --------------  -----
# 728 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
df['3PAr'].unique()
# Out:
# array([0.166, 0.081, 0.46 , 0.457, 0.249, 0.283, 0.379, 0.341, 0.164,
#        0.319, 0.38 , 0.083, 0.576, 0.374, 0.194, 0.233, 0.156, 0.427,
#        0.447, 0.401, 0.45 , 0.258, 0.454, 0.005, 0.524, 0.372, 0.487,
#        0.091, 0.513, 0.181, 0.652, 0.286, 0.476, 0.397, 0.394, 0.402,
#        0.505, 0.594, 0.32 , 0.007, 0.456, 0.606, 0.041, 0.366, 0.535,
#        0.525, 0.583, 0.455, 0.526, 0.59 , 0.271, 0.702, 0.326, 0.751,
#        0.305, 0.289, 0.464, 0.193, 0.611, 0.343, 0.467, 0.293, 0.422,
#        0.603, 0.658, 0.482, 0.51 , 0.243, 0.509, 0.479, 0.56 , 0.41 ,
#        0.016, 0.629, 0.668, 0.691, 0.634, 0.528, 0.575, 0.557, 0.638,
#        0.318, 0.555, 0.662, 0.438, 0.315, 0.612, 0.009, 0.29 , 0.622,
#        0.332, 0.406, 0.238, 0.314, 0.144, 0.356, 0.313, 0.333, 0.287,
#        0.605, 0.514, 0.37 , 0.113, 0.183, 0.616, 0.411, 0.423, 0.396,
#        0.426, 0.344, 0.539, 0.54 , 0.268, 0.5  , 0.484, 0.485, 0.392,
# ...

# %%
df['3PAr'] = pd.to_numeric(df['3PAr'], errors='coerce')
par_mean = df['3PAr'].mean()
df['3PAr'] = df['3PAr'].fillna(par_mean)
df['3PAr'].info()
df['3PAr'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: 3PAr
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([0.166     , 0.081     , 0.46      , 0.457     , 0.249     ,
#        0.283     , 0.379     , 0.341     , 0.164     , 0.319     ,
#        0.38      , 0.083     , 0.576     , 0.374     , 0.194     ,
#        0.233     , 0.156     , 0.427     , 0.447     , 0.401     ,
#        0.45      , 0.258     , 0.454     , 0.005     , 0.524     ,
#        0.372     , 0.487     , 0.091     , 0.513     , 0.181     ,
#        0.652     , 0.286     , 0.476     , 0.397     , 0.394     ,
#        0.402     , 0.505     , 0.594     , 0.32      , 0.007     ,
#        0.456     , 0.606     , 0.041     , 0.366     , 0.535     ,
#        0.525     , 0.583     , 0.455     , 0.526     , 0.59      ,
#        0.271     , 0.702     , 0.326     , 0.751     , 0.305     ,
# ...

# %%
par_counts=df['3PAr'].value_counts()
par_counts
# Out:
# 3PAr
# 0.000000    38
# 0.333000    15
# 0.500000    14
# 0.410845     8
# 0.833000     6
#             ..
# 0.800000     1
# 0.368000     1
# 0.444000     1
# 0.857000     1
# 0.395000     1
# Name: count, Length: 423, dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['3PAr'], bins=30, edgecolor='black')  # Using a histogram for continuous data
plt.xlabel('3-Point Attempt Rate (3PAr)')
plt.ylabel('Frequency')
plt.title('Distribution of 3PAr')
plt.grid(True)
plt.show()

# %% [markdown]
# ## ftr

# %%
df['FTr'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: FTr
# Non-Null Count  Dtype
# --------------  -----
# 728 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
df['FTr'].unique()
# Out:
# array([0.452, 0.389, 0.215, 0.245, 0.397, 0.295, 0.179, 0.325, 0.31 ,
#        0.302, 0.169, 0.402, 0.225, 0.273, 0.312, 0.358, 0.267, 0.349,
#        0.289, 0.266, 0.368, 0.107, 0.264, 0.635, 0.127, 0.174, 0.403,
#        0.571, 0.102, 0.436, 0.216, 0.318, 0.235, 0.23 , 0.178, 0.418,
#        0.35 , 0.383, 0.222, 0.224, 0.381, 0.177, 0.193, 0.149, 0.16 ,
#        0.268, 0.181, 0.114, 0.185, 0.239, 0.048, 0.291, 0.246, 0.269,
#        0.376, 0.121, 0.183, 0.104, 0.34 , 0.19 , 0.236, 0.133, 0.191,
#        0.217, 0.223, 0.311, 0.146, 0.186, 0.069, 0.064, 0.078, 0.132,
#        0.328, 0.321, 0.355, 0.197, 0.231, 0.359, 0.173, 0.337, 0.251,
#        0.119, 0.309, 0.126, 0.416, 0.356, 0.281, 0.198, 0.579, 0.154,
#        0.256, 0.307, 0.218, 0.274, 0.135, 0.113, 0.27 , 0.065, 0.068,
#        0.061, 0.347, 0.292, 0.404, 0.09 , 0.06 , 0.285, 0.242, 0.248,
#        0.208, 0.43 , 0.209, 0.333, 0.244, 0.261, 0.187, 0.331, 0.32 ,
# ...

# %%
df['FTr'] = pd.to_numeric(df['FTr'], errors='coerce')
ftr_mean = df['FTr'].mean()
df['FTr'] = df['FTr'].fillna(ftr_mean)
df['FTr'].info()
df['FTr'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: FTr
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([0.452     , 0.389     , 0.215     , 0.245     , 0.397     ,
#        0.295     , 0.179     , 0.325     , 0.31      , 0.302     ,
#        0.169     , 0.402     , 0.225     , 0.273     , 0.312     ,
#        0.358     , 0.267     , 0.349     , 0.289     , 0.266     ,
#        0.368     , 0.107     , 0.264     , 0.635     , 0.127     ,
#        0.174     , 0.403     , 0.571     , 0.102     , 0.436     ,
#        0.216     , 0.318     , 0.235     , 0.23      , 0.178     ,
#        0.418     , 0.35      , 0.383     , 0.222     , 0.224     ,
#        0.381     , 0.177     , 0.193     , 0.149     , 0.16      ,
#        0.268     , 0.181     , 0.114     , 0.185     , 0.239     ,
#        0.048     , 0.291     , 0.246     , 0.269     , 0.376     ,
# ...

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['FTr'], bins=30, edgecolor='black')
plt.xlabel('Free Throw Attempt Rate (FTr)')
plt.ylabel('Frequency')
plt.title('Distribution of FTr')
plt.grid(True)
plt.show()

# %% [markdown]
# ## orb%

# %%
df['ORB%'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: ORB%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
df['ORB%'].unique()
# Out:
# array([ 1.6, 11. ,  1.7,  2.5,  3.4,  2.3,  2.2,  9.3,  1.8,  5.3, 10.4,
#         1.3,  2.8,  5.8,  4.3,  7.4,  2.9,  1.5,  8.8, 13.1,  4.5,  3. ,
#         8.6,  4.7,  1.9,  2.7, 11.3,  6.1,  6.2,  5.4,  3.1,  2.4,  3.7,
#         1.4,  4. ,  2. ,  3.6,  4.2,  3.9,  3.8,  6.7,  0.7,  4.4,  4.1,
#         4.9,  1.1,  9.7,  1.2,  8.2,  3.2,  7.3, 12.8,  8.5,  5. ,  9.5,
#         3.3,  2.1,  5.5,  0.8,  6.4,  7.9,  0.9,  1. ,  6.6,  3.5,  5.2,
#         6. , 10.9,  9.2, 14.4, 18.7,  2.6, 11.4, 11.5, 11.8, 10.7,  6.9,
#         8.4,  5.6,  9.4,  6.5,  6.8, 13. , 12.3, 13.3, 13.2,  8.9,  7.1,
#         0. ,  5.1,  8.3,  5.7,  9.6, 10.8, 21.5, 11.9,  4.8,  8.7,  8.1,
#         0.3, 10.5, 10.2, 15.3,  7.2, 12.1,  6.3,  9.8,  9.9, 13.5,  7.7,
#        18.6, 12.7, 13.8, 20.7, 12.2,  9.1,  7.5,  7. , 11.7, 11.1, 13.7,
#        12.5, 15.1, 14.7, 16.3, 22.8,  4.6, 15.6,  5.9,  7.8, 13.6, 17.9,
#        16.9, 10.3,  0.5, 12. , 19.6,  9. , 11.6, 15.7, 31.6, 10.1, 27.4,
# ...

# %%
df['ORB%'] = pd.to_numeric(df['ORB%'], errors='coerce')
orb_mean = df['ORB%'].mean()
df['ORB%'] = df['ORB%'].fillna(orb_mean)
df['ORB%'].info()
df['ORB%'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: ORB%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ 1.6, 11. ,  1.7,  2.5,  3.4,  2.3,  2.2,  9.3,  1.8,  5.3, 10.4,
#         1.3,  2.8,  5.8,  4.3,  7.4,  2.9,  1.5,  8.8, 13.1,  4.5,  3. ,
#         8.6,  4.7,  1.9,  2.7, 11.3,  6.1,  6.2,  5.4,  3.1,  2.4,  3.7,
#         1.4,  4. ,  2. ,  3.6,  4.2,  3.9,  3.8,  6.7,  0.7,  4.4,  4.1,
#         4.9,  1.1,  9.7,  1.2,  8.2,  3.2,  7.3, 12.8,  8.5,  5. ,  9.5,
#         3.3,  2.1,  5.5,  0.8,  6.4,  7.9,  0.9,  1. ,  6.6,  3.5,  5.2,
#         6. , 10.9,  9.2, 14.4, 18.7,  2.6, 11.4, 11.5, 11.8, 10.7,  6.9,
#         8.4,  5.6,  9.4,  6.5,  6.8, 13. , 12.3, 13.3, 13.2,  8.9,  7.1,
#         0. ,  5.1,  8.3,  5.7,  9.6, 10.8, 21.5, 11.9,  4.8,  8.7,  8.1,
#         0.3, 10.5, 10.2, 15.3,  7.2, 12.1,  6.3,  9.8,  9.9, 13.5,  7.7,
# ...

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['ORB%'], bins=30, edgecolor='black')
plt.xlabel('Offensive Rebound Percentage (ORB%)')
plt.ylabel('Frequency')
plt.title('Distribution of ORB%')
plt.grid(True)
plt.show()

# %% [markdown]
# ## drb%

# %%
df['DRB%'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: DRB%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
df['DRB%'].unique()
# Out:
# array([ 11.3,  32.3,  12.4,  12. ,  20. ,  17.5,  14.4,  14.8,  29.6,
#          9.7,  22.8,  28.3,   9.9,  11.8,  18.1,  15.9,  20.3,  20.9,
#         11.9,   9.5,  24.4,  25.8,  29.2,  13.9,  19.5,  27. ,  19.3,
#         14.7,  10.6,  15.3,   9.2,   8.5,  10.3,   8.9,  11.1,  21.3,
#         12.9,  27.3,  23.1,  13. ,   6.8,   8.8,  17.7,  11.2,   8.4,
#         13.4,  11.4,  15.7,  15.6,   9.4,  10.2,  13.2,  22.1,  10. ,
#         13.5,  16.5,  16.1,  17.1,   9.1,   8.3,  14.2,   9. ,  16.9,
#         10.9,  12.6,  10.1,   6.7,  12.2,  10.8,  15. ,  11. ,  10.5,
#         30.7,   8.7,  18.9,  31.7,  22.9,   7.1,  21.5,  13.1,  15.1,
#         22.6,  24.8,   9.8,  13.7,  16.7,  17.9,  19.2,   7.3,  12.1,
#         30.6,   7.5,  24. ,  22.7,   6. ,   8.2,  26.5,  14. ,  14.9,
#         11.6,  16. ,  17.8,  15.5,  19.6,   7.2,  21.1,  23.9,  26.2,
#         28.9,  33. ,  24.2,  19. ,  20.5,  17. ,  19.7,  15.4,  12.8,
# ...

# %%
df['DRB%'] = pd.to_numeric(df['DRB%'], errors='coerce')
drb_mean = df['DRB%'].mean()
df['DRB%'] = df['DRB%'].fillna(drb_mean)
df['DRB%'].info()
df['DRB%'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: DRB%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ 11.3,  32.3,  12.4,  12. ,  20. ,  17.5,  14.4,  14.8,  29.6,
#          9.7,  22.8,  28.3,   9.9,  11.8,  18.1,  15.9,  20.3,  20.9,
#         11.9,   9.5,  24.4,  25.8,  29.2,  13.9,  19.5,  27. ,  19.3,
#         14.7,  10.6,  15.3,   9.2,   8.5,  10.3,   8.9,  11.1,  21.3,
#         12.9,  27.3,  23.1,  13. ,   6.8,   8.8,  17.7,  11.2,   8.4,
#         13.4,  11.4,  15.7,  15.6,   9.4,  10.2,  13.2,  22.1,  10. ,
#         13.5,  16.5,  16.1,  17.1,   9.1,   8.3,  14.2,   9. ,  16.9,
#         10.9,  12.6,  10.1,   6.7,  12.2,  10.8,  15. ,  11. ,  10.5,
#         30.7,   8.7,  18.9,  31.7,  22.9,   7.1,  21.5,  13.1,  15.1,
#         22.6,  24.8,   9.8,  13.7,  16.7,  17.9,  19.2,   7.3,  12.1,
# ...

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['DRB%'], bins=30, edgecolor='black')
plt.xlabel('Defensive Rebound Percentage (DRB%)')
plt.ylabel('Frequency')
plt.title('Distribution of DRB%')
plt.grid(True)
plt.show()

# %% [markdown]
# ## trb%

# %%
df['TRB%'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: TRB%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
df['TRB%'] = pd.to_numeric(df['TRB%'], errors='coerce')
trb_mean = df['TRB%'].mean()
df['TRB%'] = df['TRB%'].fillna(trb_mean)
df['TRB%'].info()
df['TRB%'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: TRB%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ 6.4, 21.4,  6.9,  7.1, 11.6, 10. ,  8.1,  8.8, 19.8,  5.7, 14. ,
#         5.6,  7.2, 11.9, 13.9, 12.3,  7.4,  5.4, 13.5, 17.1,  8.7, 21.5,
#         9.1, 11. ,  6.8, 17.9, 12.2,  6.6, 11.5,  5.3,  4.9,  6. ,  8.4,
#        18.7, 13.6, 17.3, 15. ,  9.3,  4.2,  6.2,  5.9,  7. , 10.6,  4.8,
#         8.9,  9.6, 10.1,  6.5, 11.4, 10.9, 12.8,  6.3,  8.5, 10.3, 10.5,
#         5.5, 10.2, 11.7,  5.2,  3.9,  7.3,  8.3,  9.4, 18.2,  7.6,  6.1,
#        19.4,  8.6, 13. , 22.8, 14.5,  5.8,  9.2, 15.4,  7.5,  7.8, 14.4,
#        14.2, 16.6,  7.9,  8. , 10.7,  9.8,  9. ,  5. , 20.9,  5.1, 16.7,
#         4.5, 18.5,  3.6, 14.1, 22.4,  7.7,  9.5,  4.7, 16.2, 17.6, 19.7,
#        19.1, 22.2, 17.2, 12.9, 13.7, 13.1, 14.6, 16.9, 12.7,  6.7, 17.7,
# ...

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['TRB%'], bins=30, edgecolor='black')
plt.xlabel('Total Rebound Percentage (TRB%)')
plt.ylabel('Frequency')
plt.title('Distribution of TRB%')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ast%

# %%
df['AST%'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: AST%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
df['AST%'].unique()
# Out:
# array([21.8, 33.9, 20.8, 16.3, 25.2, 22.2, 27.9, 24.6, 42. , 33.5, 15.5,
#        31.1, 19.4, 22.1, 16.5, 21. , 23.5, 26.7, 44.3, 15.2, 17.3,  5.6,
#         6.9, 14.6, 28.8, 32.7,  6.7, 29.8, 12.1, 37.5, 16.1, 28. , 27.6,
#        33.6, 31.2, 13.2,  7.1, 24.7, 18.9, 11.6,  9.5, 14.9, 21.2, 13.8,
#        13.7, 21.4, 16.6,  6.1, 18.8, 16.9, 11.3, 11.2, 20.7, 19.3, 17.8,
#        19.1,  6.3,  7.5, 44.9, 21.3,  9.3, 11.5,  6.2, 20.2, 15.6, 26.5,
#        28.4, 16. , 14.5, 12.9, 17.1, 22.7, 27.5, 12.2, 30.8,  8.2, 15.7,
#        13.1,  9.2, 10.4, 13.9,  7.2, 21.5,  6.8, 26.2, 19.9,  6.4, 29.5,
#        10.7,  6. ,  7.3, 23.1, 16.4, 31.3, 23.4, 14.2, 23.8, 15.1, 15. ,
#        26.6,  7.8,  6.6,  8.6,  5.9, 15.9, 18.1,  8.3, 25.7, 14.3, 12.5,
#        28.3, 45.1,  7.6, 34.6, 13.3, 29.4, 13.5, 10. , 15.4,  8.5, 28.9,
#        12.3, 16.7, 12.8, 19.5, 23. , 19.8,  9.1,  8. , 11.1,  8.8,  5.5,
#        25. , 12.7, 22.5, 29.9,  4.5, 29.6, 24.8, 11.8,  9.4,  9. , 11.4,
# ...

# %%
df['AST%'] = pd.to_numeric(df['AST%'], errors='coerce')
ast_mean = df['AST%'].mean()
df['AST%'] = df['AST%'].fillna(ast_mean)
df['AST%'].info()
df['AST%'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: AST%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([21.8, 33.9, 20.8, 16.3, 25.2, 22.2, 27.9, 24.6, 42. , 33.5, 15.5,
#        31.1, 19.4, 22.1, 16.5, 21. , 23.5, 26.7, 44.3, 15.2, 17.3,  5.6,
#         6.9, 14.6, 28.8, 32.7,  6.7, 29.8, 12.1, 37.5, 16.1, 28. , 27.6,
#        33.6, 31.2, 13.2,  7.1, 24.7, 18.9, 11.6,  9.5, 14.9, 21.2, 13.8,
#        13.7, 21.4, 16.6,  6.1, 18.8, 16.9, 11.3, 11.2, 20.7, 19.3, 17.8,
#        19.1,  6.3,  7.5, 44.9, 21.3,  9.3, 11.5,  6.2, 20.2, 15.6, 26.5,
#        28.4, 16. , 14.5, 12.9, 17.1, 22.7, 27.5, 12.2, 30.8,  8.2, 15.7,
#        13.1,  9.2, 10.4, 13.9,  7.2, 21.5,  6.8, 26.2, 19.9,  6.4, 29.5,
#        10.7,  6. ,  7.3, 23.1, 16.4, 31.3, 23.4, 14.2, 23.8, 15.1, 15. ,
#        26.6,  7.8,  6.6,  8.6,  5.9, 15.9, 18.1,  8.3, 25.7, 14.3, 12.5,
# ...

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['AST%'], bins=30, edgecolor='black')
plt.xlabel('Assist Percentage (AST%)')
plt.ylabel('Frequency')
plt.title('Distribution of AST%')
plt.grid(True)
plt.show()

# %% [markdown]
# ## stl%

# %%
df['STL%'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: STL%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
df['STL%'].unique()
# Out:
# array([ 1.5,  1.2,  0.9,  1.4,  1.3,  1.9,  1.8,  2. ,  1.6,  2.7,  1.1,
#         1. ,  0.8,  2.8,  1.7,  2.2,  2.3,  2.4,  2.9,  2.6,  0.6,  0.7,
#         2.5,  2.1,  3.8,  3.1,  0.5,  3.2,  0. ,  3.5,  3.6,  3.3,  6.6,
#         5.2,  4.2,  3.9,  4.3,  0.3,  0.4,  3.4,  4.7,  3. ,  6. ,  5.7,
#         8. ,  6.1,  4.9,  5. ,  5.5,  6.3, 18.7, 12.1])

# %%
df['STL%'] = pd.to_numeric(df['STL%'], errors='coerce')
stl_mean = df['STL%'].mean()
df['STL%'] = df['STL%'].fillna(stl_mean)
df['STL%'].info()
df['STL%'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: STL%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ 1.5,  1.2,  0.9,  1.4,  1.3,  1.9,  1.8,  2. ,  1.6,  2.7,  1.1,
#         1. ,  0.8,  2.8,  1.7,  2.2,  2.3,  2.4,  2.9,  2.6,  0.6,  0.7,
#         2.5,  2.1,  3.8,  3.1,  0.5,  3.2,  0. ,  3.5,  3.6,  3.3,  6.6,
#         5.2,  4.2,  3.9,  4.3,  0.3,  0.4,  3.4,  4.7,  3. ,  6. ,  5.7,
#         8. ,  6.1,  4.9,  5. ,  5.5,  6.3, 18.7, 12.1])

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['STL%'], bins=30, edgecolor='black')
plt.xlabel('Steal Percentage (STL%)')
plt.ylabel('Frequency')
plt.title('Distribution of STL%')
plt.grid(True)
plt.show()

# %% [markdown]
# ## blk%

# %%
df['BLK%'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: BLK%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB

# %%
df['BLK%'].unique()
# Out:
# array([ 1.5,  0.6,  0.9,  1.6,  2.9,  0.8,  1.3,  2.1,  0.4,  5.7,  2. ,
#         1.1,  0.7,  1.4,  2.4,  1. ,  5.5,  1.2,  2.6,  1.8,  0.5,  3. ,
#         2.3,  2.7,  7.3,  6.7,  3.2,  0.3,  1.7,  1.9,  2.5,  4.7,  0.2,
#         6.2, 10. ,  3.7,  3.4,  3.5,  2.2,  3.3,  4.2,  5.1,  7.1,  6.6,
#         7.9,  3.9,  3.1,  5.8,  4.4,  4.8,  2.8,  9.2,  5. ,  3.8,  3.6,
#         4.6,  5.2,  0.1,  0. ,  4.1,  6.1,  4.5,  7. ,  4.3,  6.3,  4. ,
#         7.4,  5.6,  6.8,  4.9,  5.4,  8. ,  6.9, 13.2,  5.3,  8.8,  8.6,
#        15.1, 12.2,  9. , 15.6])

# %%
df['BLK%'] = pd.to_numeric(df['BLK%'], errors='coerce')
blk_mean = df['BLK%'].mean()
df['BLK%'] = df['BLK%'].fillna(blk_mean)
df['BLK%'].info()
df['BLK%'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: BLK%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ 1.5,  0.6,  0.9,  1.6,  2.9,  0.8,  1.3,  2.1,  0.4,  5.7,  2. ,
#         1.1,  0.7,  1.4,  2.4,  1. ,  5.5,  1.2,  2.6,  1.8,  0.5,  3. ,
#         2.3,  2.7,  7.3,  6.7,  3.2,  0.3,  1.7,  1.9,  2.5,  4.7,  0.2,
#         6.2, 10. ,  3.7,  3.4,  3.5,  2.2,  3.3,  4.2,  5.1,  7.1,  6.6,
#         7.9,  3.9,  3.1,  5.8,  4.4,  4.8,  2.8,  9.2,  5. ,  3.8,  3.6,
#         4.6,  5.2,  0.1,  0. ,  4.1,  6.1,  4.5,  7. ,  4.3,  6.3,  4. ,
#         7.4,  5.6,  6.8,  4.9,  5.4,  8. ,  6.9, 13.2,  5.3,  8.8,  8.6,
#        15.1, 12.2,  9. , 15.6])

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['BLK%'], bins=30, edgecolor='black')
plt.xlabel('Block Percentage (BLK%)')
plt.ylabel('Frequency')
plt.title('Distribution of BLK%')
plt.grid(True)
plt.show()

# %% [markdown]
# ## tov %

# %%
df['TOV%'].info()
df['TOV%'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: TOV%
# Non-Null Count  Dtype
# --------------  -----
# 729 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([  7.7,  17.9,  11.1,  10.3,  13. ,  13.1,  11.3,  11.9,  12.9,
#          9.1,  13.9,   9.5,  10.1,   8.9,   7.4,  14.1,   6.8,  12.8,
#          8.6,  11.4,   5.9,   9.6,  12.7,   7.5,   8.4,  14.5,  11.7,
#         15. ,  11.8,  16. ,  10.6,  11.2,  12. ,  10.9,   8.8,  10.5,
#          8.7,  10.2,   6.6,  11. ,   8.2,   9.7,  10.7,  10. ,   8.5,
#         12.4,  14.7,  14.8,   9.3,  12.2,   9.9,  14.3,  10.4,   9. ,
#          9.8,  15.1,  13.4,   6.2,  10.8,  16.2,  11.6,  13.6,  19.1,
#          9.4,  12.1,   6.4,  12.5,  14.9,   7.9,   8. ,  14.4,  17.1,
#         15.7,   5. ,   7.3,   9.2,   7.6,  13.2,  16.5,  16.1,  17.6,
#         13.3,  12.3,   7.1,  15.6,  16.7,  14.2,  19.3,  13.8,  20.9,
# ...

# %%
df['TOV%'] = pd.to_numeric(df['TOV%'], errors='coerce')
tov_mean = df['TOV%'].mean()
df['TOV%'] = df['TOV%'].fillna(tov_mean)
df['TOV%'].info()
df['TOV%'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: TOV%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([  7.7       ,  17.9       ,  11.1       ,  10.3       ,
#         13.        ,  13.1       ,  11.3       ,  11.9       ,
#         12.9       ,   9.1       ,  13.9       ,   9.5       ,
#         10.1       ,   8.9       ,   7.4       ,  14.1       ,
#          6.8       ,  12.8       ,   8.6       ,  11.4       ,
#          5.9       ,   9.6       ,  12.7       ,   7.5       ,
#          8.4       ,  14.5       ,  11.7       ,  15.        ,
#         11.8       ,  16.        ,  10.6       ,  11.2       ,
#         12.        ,  10.9       ,   8.8       ,  10.5       ,
#          8.7       ,  10.2       ,   6.6       ,  11.        ,
#          8.2       ,   9.7       ,  10.7       ,  10.        ,
#          8.5       ,  12.4       ,  14.7       ,  14.8       ,
# ...

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['TOV%'], bins=30, edgecolor='black')
plt.xlabel('Turnover Percentage (TOV%)')
plt.ylabel('Frequency')
plt.title('Distribution of TOV%')
plt.grid(True)
plt.show()

# %% [markdown]
# ## usg

# %%
df['USG%'].info()
df['USG%'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: USG%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([25.8, 22.2, 22.7, 24.3, 29.7, 29. , 26.6, 32.3, 29.3, 32.5, 13.5,
#        26.7, 19.7, 31. , 25.3, 25.2, 30.2, 20.3, 28. , 36. , 23.3, 27.4,
#        15.4, 18.1, 24.7, 28.4, 33. , 20.7, 32.8, 14.5, 29.2, 19.4, 21.8,
#        23. , 20.6, 29.8, 17.6, 31.3, 24.9, 21.6, 16. , 12.9, 22.3, 23.9,
#        15.7, 18.6, 21.3, 26.4, 28.9, 14.6, 25.7, 26.5, 14.1, 17.8, 24.2,
#        16.3, 20.2, 23.5, 17.4, 24.6, 23.7, 19.1, 21.2, 17.2, 18.8, 19.2,
#        16.6, 12.2, 15.2, 15.9, 13.6, 19. , 30.4, 22.6, 15.6, 18.7, 13.8,
#        32.2, 27.2, 24.8, 23.4, 27.5, 30.5, 30.8, 19.6, 17. , 22.4, 27. ,
#        24. , 14.7, 25.9, 27.8, 23.8, 21.9, 28.1, 22.8, 23.1, 22.9, 20. ,
#        24.4, 13.9, 24.1, 31.4, 13.2, 20.8, 14.8, 20.9, 20.4, 12. , 16.5,
# ...

# %%
df['USG%'] = pd.to_numeric(df['USG%'], errors='coerce')
usg_mean = df['USG%'].mean()
df['USG%'] = df['USG%'].fillna(usg_mean)
df['USG%'].info()
df['USG%'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: USG%
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([25.8, 22.2, 22.7, 24.3, 29.7, 29. , 26.6, 32.3, 29.3, 32.5, 13.5,
#        26.7, 19.7, 31. , 25.3, 25.2, 30.2, 20.3, 28. , 36. , 23.3, 27.4,
#        15.4, 18.1, 24.7, 28.4, 33. , 20.7, 32.8, 14.5, 29.2, 19.4, 21.8,
#        23. , 20.6, 29.8, 17.6, 31.3, 24.9, 21.6, 16. , 12.9, 22.3, 23.9,
#        15.7, 18.6, 21.3, 26.4, 28.9, 14.6, 25.7, 26.5, 14.1, 17.8, 24.2,
#        16.3, 20.2, 23.5, 17.4, 24.6, 23.7, 19.1, 21.2, 17.2, 18.8, 19.2,
#        16.6, 12.2, 15.2, 15.9, 13.6, 19. , 30.4, 22.6, 15.6, 18.7, 13.8,
#        32.2, 27.2, 24.8, 23.4, 27.5, 30.5, 30.8, 19.6, 17. , 22.4, 27. ,
#        24. , 14.7, 25.9, 27.8, 23.8, 21.9, 28.1, 22.8, 23.1, 22.9, 20. ,
#        24.4, 13.9, 24.1, 31.4, 13.2, 20.8, 14.8, 20.9, 20.4, 12. , 16.5,
# ...

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['USG%'], bins=30, edgecolor='black')
plt.xlabel('Usage Percentage (USG%)')
plt.ylabel('Frequency')
plt.title('Distribution of USG%')
plt.grid(True)
plt.show()

# %% [markdown]
# ## ows

# %%
df['OWS'].info()
df['OWS'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: OWS
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ 7. ,  8.6,  3.1,  2.1,  1.3,  5.1,  3.3,  2.9, 12. ,  8.8,  2. ,
#         7.2,  5.3,  5.4,  2.4,  3. ,  6.4,  3.9,  5.9,  8.5,  2.7,  0.2,
#         5.8,  2.6,  0.7,  9.5, 10.5,  4.7,  5.7,  4.4,  2.3,  0.3,  6.8,
#         5.2,  4.6,  2.2,  2.8, -0.3,  3.2,  3.6, -1.5,  1.9,  6. ,  4.5,
#         1.8, -1. ,  1.7,  1.2,  0.6,  7.6,  0. , -0.5,  5. ,  3.5,  3.4,
#         0.4,  0.9,  0.8,  1.4, -0.7,  3.8,  1.6,  1.5,  4.9, -0.4,  1.1,
#         1. ,  4. ,  0.5,  4.2, -2.5,  2.5,  0.1, -0.6, -0.9, -0.2, -0.1,
#        -1.1,  nan])

# %%
df['OWS'] = pd.to_numeric(df['OWS'], errors='coerce')
ows_mean = df['OWS'].mean()
df['OWS'] = df['OWS'].fillna(ows_mean)
df['OWS'].info()
df['OWS'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: OWS
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ 7.        ,  8.6       ,  3.1       ,  2.1       ,  1.3       ,
#         5.1       ,  3.3       ,  2.9       , 12.        ,  8.8       ,
#         2.        ,  7.2       ,  5.3       ,  5.4       ,  2.4       ,
#         3.        ,  6.4       ,  3.9       ,  5.9       ,  8.5       ,
#         2.7       ,  0.2       ,  5.8       ,  2.6       ,  0.7       ,
#         9.5       , 10.5       ,  4.7       ,  5.7       ,  4.4       ,
#         2.3       ,  0.3       ,  6.8       ,  5.2       ,  4.6       ,
#         2.2       ,  2.8       , -0.3       ,  3.2       ,  3.6       ,
#        -1.5       ,  1.9       ,  6.        ,  4.5       ,  1.8       ,
#        -1.        ,  1.7       ,  1.2       ,  0.6       ,  7.6       ,
# ...

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['OWS'], bins=30, edgecolor='black')
plt.xlabel('Offensive Win Shares (OWS)')
plt.ylabel('Frequency')
plt.title('Distribution of OWS')
plt.grid(True)
plt.show()

# %% [markdown]
# ## dws

# %%
df['DWS'].info()
df['DWS'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: DWS
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([2.2, 4. , 1.6, 2.1, 3.2, 4.7, 5.1, 2.4, 3.6, 3.1, 1.5, 0.6, 0.9,
#        4.1, 2. , 3.5, 2.8, 2.9, 5.8, 2.6, 1.4, 1.9, 3.7, 4.2, 1. , 0.5,
#        1.8, 2.5, 3.9, 4.3, 4.4, 1.2, 3.3, 2.7, 3. , 0.8, 1.7, 1.1, 1.3,
#        0.4, 0.3, 3.8, 0.7, 0.1, 2.3, 0.2, 0. , nan])

# %%
df['DWS'] = pd.to_numeric(df['DWS'], errors='coerce')
dws_mean = df['DWS'].mean()
df['DWS'] = df['DWS'].fillna(dws_mean)
df['DWS'].info()
df['DWS'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: DWS
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([2.2       , 4.        , 1.6       , 2.1       , 3.2       ,
#        4.7       , 5.1       , 2.4       , 3.6       , 3.1       ,
#        1.5       , 0.6       , 0.9       , 4.1       , 2.        ,
#        3.5       , 2.8       , 2.9       , 5.8       , 2.6       ,
#        1.4       , 1.9       , 3.7       , 4.2       , 1.        ,
#        0.5       , 1.8       , 2.5       , 3.9       , 4.3       ,
#        4.4       , 1.2       , 3.3       , 2.7       , 3.        ,
#        0.8       , 1.7       , 1.1       , 1.3       , 0.4       ,
#        0.3       , 3.8       , 0.7       , 0.1       , 2.3       ,
#        0.2       , 0.        , 0.90272109])

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['DWS'], bins=30, edgecolor='black')
plt.xlabel('Defensive Win Shares (DWS)')
plt.ylabel('Frequency')
plt.title('Distribution of DWS')
plt.grid(True)
plt.show()

# %% [markdown]
# ## ws

# %%
df['WS'].info()
df['WS'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: WS
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ 9.2, 12.6,  4.7,  4.2,  5.3,  8.3,  4.9,  7.5, 17. , 11.2,  5.7,
#        11.8,  8.4,  6.5,  6.9,  3. ,  3.9, 10.4,  5.9,  8.1, 12. ,  5.4,
#         3.1, 11.6,  5.2,  2.2,  7.7, 13.2,  6.2, 14.6,  8.5,  7.3,  3.3,
#         2.5,  0.8,  5.1, 10.7,  5.6,  7.2,  8.9,  4.8,  6.6, -0.6,  3.5,
#         6.4,  6.3,  7.1,  3.6,  0.2,  3.2,  4.6,  2.7,  9. ,  1.9,  1.1,
#         0.5,  4.1,  8.2,  1.4,  2. ,  1.5,  2.9,  0.7,  2.6,  1.3,  6.7,
#         4. ,  3.7,  3.4,  4.3,  5.8,  5.5,  1.8,  2.1,  9.1, -0.3,  1.7,
#         4.5,  2.8,  4.4,  3.8,  2.4,  6.1,  7.8,  6.8, -1.7,  0.4,  1. ,
#         1.6,  7.9,  0.1,  0.9,  0.3,  1.2, -0.4,  0. ,  0.6,  2.3, -0.2,
#        -0.5, -0.1, -0.8,  nan])

# %%
df['WS'] = pd.to_numeric(df['WS'], errors='coerce')
ws_mean = df['WS'].mean()
df['WS'] = df['WS'].fillna(ws_mean)
df['WS'].info()
df['WS'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: WS
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ 9.2       , 12.6       ,  4.7       ,  4.2       ,  5.3       ,
#         8.3       ,  4.9       ,  7.5       , 17.        , 11.2       ,
#         5.7       , 11.8       ,  8.4       ,  6.5       ,  6.9       ,
#         3.        ,  3.9       , 10.4       ,  5.9       ,  8.1       ,
#        12.        ,  5.4       ,  3.1       , 11.6       ,  5.2       ,
#         2.2       ,  7.7       , 13.2       ,  6.2       , 14.6       ,
#         8.5       ,  7.3       ,  3.3       ,  2.5       ,  0.8       ,
#         5.1       , 10.7       ,  5.6       ,  7.2       ,  8.9       ,
#         4.8       ,  6.6       , -0.6       ,  3.5       ,  6.4       ,
#         6.3       ,  7.1       ,  3.6       ,  0.2       ,  3.2       ,
# ...

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['WS'], bins=30, edgecolor='black')
plt.xlabel('Win Shares (WS)')
plt.ylabel('Frequency')
plt.title('Distribution of WS')
plt.grid(True)
plt.show()

# %% [markdown]
# ## ws/48

# %%
df['WS/48'].info()
df['WS/48'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: WS/48
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ 1.47e-01,  2.06e-01,  7.80e-02,  7.00e-02,  9.00e-02,  1.42e-01,
#         8.40e-02,  1.30e-01,  2.99e-01,  1.98e-01,  1.00e-01,  2.10e-01,
#         1.50e-01,  1.17e-01,  1.24e-01,  1.06e-01,  1.43e-01,  1.89e-01,
#         1.08e-01,  2.20e-01,  5.60e-02,  2.16e-01,  9.60e-02,  4.00e-02,
#         2.46e-01,  1.15e-01,  2.75e-01,  1.32e-01,  1.64e-01,  1.40e-01,
#         6.30e-02,  7.60e-02,  4.20e-02,  9.90e-02,  1.63e-01,  1.81e-01,
#         1.11e-01,  1.44e-01,  1.78e-01,  7.90e-02,  1.50e-02,  9.40e-02,
#         1.71e-01,  1.21e-01,  1.35e-01, -1.30e-02,  7.30e-02,  1.31e-01,
#         1.84e-01,  1.48e-01,  7.50e-02,  4.00e-03,  1.33e-01,  6.80e-02,
#         7.70e-02,  9.70e-02,  8.30e-02,  5.80e-02,  1.95e-01,  1.57e-01,
# ...

# %%
df['WS/48'] = pd.to_numeric(df['WS/48'], errors='coerce')
ws48_mean = df['WS/48'].mean()
df['WS/48'] = df['WS/48'].fillna(ws48_mean)
df['WS/48'].info()
df['WS/48'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: WS/48
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ 1.47000000e-01,  2.06000000e-01,  7.80000000e-02,  7.00000000e-02,
#         9.00000000e-02,  1.42000000e-01,  8.40000000e-02,  1.30000000e-01,
#         2.99000000e-01,  1.98000000e-01,  1.00000000e-01,  2.10000000e-01,
#         1.50000000e-01,  1.17000000e-01,  1.24000000e-01,  1.06000000e-01,
#         1.43000000e-01,  1.89000000e-01,  1.08000000e-01,  2.20000000e-01,
#         5.60000000e-02,  2.16000000e-01,  9.60000000e-02,  4.00000000e-02,
#         2.46000000e-01,  1.15000000e-01,  2.75000000e-01,  1.32000000e-01,
#         1.64000000e-01,  1.40000000e-01,  6.30000000e-02,  7.60000000e-02,
#         4.20000000e-02,  9.90000000e-02,  1.63000000e-01,  1.81000000e-01,
#         1.11000000e-01,  1.44000000e-01,  1.78000000e-01,  7.90000000e-02,
# ...

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['WS/48'], bins=30, edgecolor='black')
plt.xlabel('Win Shares per 48 Minutes (WS/48)')
plt.ylabel('Frequency')
plt.title('Distribution of WS/48')
plt.grid(True)
plt.show()

# %% [markdown]
# ## obpm

# %%
df['OBPM'].info()
df['OBPM'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: OBPM
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([  2.1,   4. ,   0.7,   1.3,   2.3,   2.7,   9. ,   6.3,  -1.3,
#          3.5,   2.6,   2.2,   3. ,   4.5,   0.9,   4.1,   8.3,   0.8,
#          0.4,   0.1,  -0.4,   0.2,   3.4,   6.7,   1.2,   1.1,   5.5,
#          2.9,  -0.5,   1.7,   3.8,   1.8,  -2.1,  -0.9,  -0.6,   2.4,
#          1. ,   2.5,  -2. ,  -1. ,   4.8,   0.5,  -0.7,  -1.4,  -1.1,
#         -3.3,   7.3,   2. ,  -1.7,  -1.8,   3.3,  -2.8,  -3.2,  -1.9,
#         -2.7,  -0.8,   0. ,  -0.3,  -2.2,  -2.6,   1.9,   1.4,  -0.2,
#         -1.5,   3.1,   3.9,   1.6,  -1.2,  -1.6,   4.6,   4.9,   1.5,
#         -2.4,  -3.1,  -2.5,   5.1,  -3.5,  -3.6,  -5. ,  -3.4,  -3. ,
#          0.3,  -0.1,   8.5,  -2.3,  -4.9,  -4. ,  -3.9,  -4.8,  -3.8,
# ...

# %%
df['OBPM'] = pd.to_numeric(df['OBPM'], errors='coerce')
obpm_mean = df['OBPM'].mean()
df['OBPM'] = df['OBPM'].fillna(obpm_mean)
df['OBPM'].info()
df['OBPM'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: OBPM
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([  2.1       ,   4.        ,   0.7       ,   1.3       ,
#          2.3       ,   2.7       ,   9.        ,   6.3       ,
#         -1.3       ,   3.5       ,   2.6       ,   2.2       ,
#          3.        ,   4.5       ,   0.9       ,   4.1       ,
#          8.3       ,   0.8       ,   0.4       ,   0.1       ,
#         -0.4       ,   0.2       ,   3.4       ,   6.7       ,
#          1.2       ,   1.1       ,   5.5       ,   2.9       ,
#         -0.5       ,   1.7       ,   3.8       ,   1.8       ,
#         -2.1       ,  -0.9       ,  -0.6       ,   2.4       ,
#          1.        ,   2.5       ,  -2.        ,  -1.        ,
#          4.8       ,   0.5       ,  -0.7       ,  -1.4       ,
#         -1.1       ,  -3.3       ,   7.3       ,   2.        ,
# ...

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['OBPM'], bins=30, edgecolor='black')
plt.xlabel('Offensive Box Plus/Minus (OBPM)')
plt.ylabel('Frequency')
plt.title('Distribution of OBPM')
plt.grid(True)
plt.show()

# %% [markdown]
# ## dbpm

# %%
df['DBPM'].info()
df['DBPM'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: DBPM
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ -0.3,   2.4,  -1.3,  -1. ,   0. ,   0.1,  -0.6,   0.5,   4.2,
#         -0.4,   1.4,   1.7,   0.8,  -0.7,  -0.8,  -0.5,   0.6,  -0.9,
#         -1.2,   2.3,   0.9,   0.2,  -1.4,   0.3,  -1.1,   1.5,   0.7,
#         -1.6,  -0.1,  -1.9,  -1.5,   1.1,  -0.2,  -1.7,   0.4,  -2.1,
#          3.3,   2.1,  -2. ,   1.6,  -2.9,   1. ,   1.2,  -2.3,   1.3,
#          2.8,   1.9,   3.4,   2.7,   2. ,   1.8,  -3.2,  -2.2,  -2.5,
#          4.4,   3. ,   2.5,   3.1,  -1.8,   2.2,  -3. ,  -7.3,  -2.8,
#          6.5,   2.9,  -3.6,   3.2,   4.5,  -2.7,  -6.1,  -2.4,  -9.2,
#         -3.5,  -3.7,   3.8,  -4.8,   5.1,   8.5,  -6.3,  -3.1,  -2.6,
#          3.7,  -5. ,  -3.4,  -8.3,  -4.2,   4. ,  -5.2,  -5.4,   7. ,
# ...

# %%
df['DBPM'] = pd.to_numeric(df['DBPM'], errors='coerce')
dbpm_mean = df['DBPM'].mean()
df['DBPM'] = df['DBPM'].fillna(dbpm_mean)
df['DBPM'].info()
df['DBPM'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: DBPM
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ -0.3       ,   2.4       ,  -1.3       ,  -1.        ,
#          0.        ,   0.1       ,  -0.6       ,   0.5       ,
#          4.2       ,  -0.4       ,   1.4       ,   1.7       ,
#          0.8       ,  -0.7       ,  -0.8       ,  -0.5       ,
#          0.6       ,  -0.9       ,  -1.2       ,   2.3       ,
#          0.9       ,   0.2       ,  -1.4       ,   0.3       ,
#         -1.1       ,   1.5       ,   0.7       ,  -1.6       ,
#         -0.1       ,  -1.9       ,  -1.5       ,   1.1       ,
#         -0.2       ,  -1.7       ,   0.4       ,  -2.1       ,
#          3.3       ,   2.1       ,  -2.        ,   1.6       ,
#         -2.9       ,   1.        ,   1.2       ,  -2.3       ,
#          1.3       ,   2.8       ,   1.9       ,   3.4       ,
# ...

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['DBPM'], bins=30, edgecolor='black')
plt.xlabel('Defensive Box Plus/Minus (DBPM)')
plt.ylabel('Frequency')
plt.title('Distribution of DBPM')
plt.grid(True)
plt.show()

# %% [markdown]
# ## bpm

# %%
df['BPM'].info()
df['BPM'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: BPM
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([  1.8,   6.5,  -0.7,  -0.4,   1.3,   4. ,   1.7,   3.3,  13.2,
#          5.8,   0. ,   5.1,   3.4,   2.7,   1.9,   1.4,   2.5,   0.4,
#          3.1,   9.9,   0.1,  -0.5,  -0.9,  -1.1,   2.1,   9. ,   3.2,
#         -1.8,  -1.9,   0.9,   4.1,   3. ,   5.2,   2.4,   1. ,  -1.4,
#          0.2,  -2.6,   3.8,  -3.9,   0.7,   1.2,   5.5,   0.6,  -1.6,
#         -0.6,  -3.6,   6.9,   2.3,  -2.1,  -2.8,  -1.2,  -3.1,  -0.8,
#         -3.4,   0.8,  -1.3,  -3.2,  -1.5,  -2.9,   3.7,   1.1,   0.3,
#         -2.3,   4.9,   4.6,   1.5,  -1.7,  -4.4,  -0.1,   2.6,  -2. ,
#         -2.5,  -1. ,   3.5,  -3.3,  -4.5,   3.6,   5.9,  -5.8,  -4.2,
#         -2.2,  -2.4,  -3. ,  -6.5,  -0.2,  -5.6,   2.9,   0.5,   2.8,
# ...

# %%
df['BPM'] = pd.to_numeric(df['BPM'], errors='coerce')
bpm_mean = df['BPM'].mean()
df['BPM'] = df['BPM'].fillna(bpm_mean)
df['BPM'].info()
df['BPM'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: BPM
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([  1.8       ,   6.5       ,  -0.7       ,  -0.4       ,
#          1.3       ,   4.        ,   1.7       ,   3.3       ,
#         13.2       ,   5.8       ,   0.        ,   5.1       ,
#          3.4       ,   2.7       ,   1.9       ,   1.4       ,
#          2.5       ,   0.4       ,   3.1       ,   9.9       ,
#          0.1       ,  -0.5       ,  -0.9       ,  -1.1       ,
#          2.1       ,   9.        ,   3.2       ,  -1.8       ,
#         -1.9       ,   0.9       ,   4.1       ,   3.        ,
#          5.2       ,   2.4       ,   1.        ,  -1.4       ,
#          0.2       ,  -2.6       ,   3.8       ,  -3.9       ,
#          0.7       ,   1.2       ,   5.5       ,   0.6       ,
#         -1.6       ,  -0.6       ,  -3.6       ,   6.9       ,
# ...

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['BPM'], bins=30, edgecolor='black')
plt.xlabel('Box Plus/Minus (BPM)')
plt.ylabel('Frequency')
plt.title('Distribution of BPM')
plt.grid(True)
plt.show()

# %% [markdown]
# ## vorp

# %%
df['VORP'].info()
df['VORP'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: VORP
# Non-Null Count  Dtype
# --------------  -----
# 735 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ 2.8,  6.2,  0.9,  1.2,  2.3,  4.3,  2.6,  3.7, 10.6,  5.4,  1.4,
#         4.9,  3.6,  3.2,  2.7,  1.5,  4.7,  1.6,  3.4,  8. ,  1. ,  2.5,
#         0.8,  0.6,  7.2,  1.3,  7.1,  2. ,  3.3,  0.1,  0. ,  1.8,  3.8,
#         3.1,  4.4,  0.4, -0.3,  3.5,  1.7, -1.2,  1.9,  0.5,  2.4,  1.1,
#         0.2, -0.9,  5. , -0.1, -0.6,  0.7,  3. , -0.8,  0.3, -0.2, -0.4,
#        -0.5,  3.9,  2.2,  2.9,  2.1, -1.7, -1.1, -1. , -0.7, -1.5,  4.5,
#         nan])

# %%
df['VORP'] = pd.to_numeric(df['VORP'], errors='coerce')
vorp_mean = df['VORP'].mean()
df['VORP'] = df['VORP'].fillna(vorp_mean)
df['VORP'].info()
df['VORP'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: VORP
# Non-Null Count  Dtype
# --------------  -----
# 736 non-null    float64
# dtypes: float64(1)
# memory usage: 5.9 KB
# array([ 2.8 ,  6.2 ,  0.9 ,  1.2 ,  2.3 ,  4.3 ,  2.6 ,  3.7 , 10.6 ,
#         5.4 ,  1.4 ,  4.9 ,  3.6 ,  3.2 ,  2.7 ,  1.5 ,  4.7 ,  1.6 ,
#         3.4 ,  8.  ,  1.  ,  2.5 ,  0.8 ,  0.6 ,  7.2 ,  1.3 ,  7.1 ,
#         2.  ,  3.3 ,  0.1 ,  0.  ,  1.8 ,  3.8 ,  3.1 ,  4.4 ,  0.4 ,
#        -0.3 ,  3.5 ,  1.7 , -1.2 ,  1.9 ,  0.5 ,  2.4 ,  1.1 ,  0.2 ,
#        -0.9 ,  5.  , -0.1 , -0.6 ,  0.7 ,  3.  , -0.8 ,  0.3 , -0.2 ,
#        -0.4 , -0.5 ,  3.9 ,  2.2 ,  2.9 ,  2.1 , -1.7 , -1.1 , -1.  ,
#        -0.7 , -1.5 ,  4.5 ,  0.42])

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['VORP'], bins=30, edgecolor='black')
plt.xlabel('Value Over Replacement Player (VORP)')
plt.ylabel('Frequency')
plt.title('Distribution of VORP')
plt.grid(True)
plt.show()

# %% [markdown]
# ## awards

# %%
df['Awards'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 736 entries, 0 to 735
# Series name: Awards
# Non-Null Count  Dtype
# --------------  -----
# 56 non-null     object
# dtypes: object(1)
# memory usage: 5.9+ KB

# %%
df['Awards'].unique()
# Out:
# array(['CPOY-2', 'MVP-8DPOY-10NBA3', nan, 'AS', 'MVP-9ASNBA2',
#        'MVP-7CPOY-8ASNBA2', 'MVP-1CPOY-4ASNBA1', 'MVP-5CPOY-5ASNBA2',
#        'DPOY-4ASNBA2DEF1', 'CPOY-12', 'MVP-6CPOY-9ASNBA1', 'MIP-1AS',
#        'MVP-3CPOY-6ASNBA1', 'DPOY-1DEF1', 'CPOY-11AS',
#        'MVP-4DPOY-9CPOY-12ASNBA1', 'MVP-2DPOY-7CPOY-3ASNBA1',
#        'CPOY-10ASNBA3', 'ASNBA3', 'DPOY-10', 'CPOY-1ASNBA3',
#        'DPOY-3ASDEF1', 'ROY-2', '6MOY-5', 'ROY-3', 'DPOY-8DEF2', 'ASNBA2',
#        'DPOY-5DEF1', 'DPOY-6DEF2', '6MOY-9', 'ROY-46MOY-9',
#        'ROY-1DPOY-2DEF1', 'DEF2', 'DPOY-10DEF2', 'CPOY-7', '6MOY-3',
#        '6MOY-4', 'ROY-5', '6MOY-1', 'CPOY-126MOY-2', '6MOY-7', 'ROY-6',
#        '6MOY-6'], dtype=object)

# %%
df['Awards']=df['Awards'].fillna('none')

# %%
awards=df['Awards'].value_counts()
awards
# Out:
# Awards
# none                        680
# AS                            9
# 6MOY-9                        3
# 6MOY-7                        2
# DPOY-10DEF2                   2
# ASNBA3                        2
# CPOY-12                       2
# MVP-8DPOY-10NBA3              1
# CPOY-2                        1
# MVP-7CPOY-8ASNBA2             1
# MVP-9ASNBA2                   1
# MVP-6CPOY-9ASNBA1             1
# DPOY-4ASNBA2DEF1              1
# MVP-5CPOY-5ASNBA2             1
# MVP-1CPOY-4ASNBA1             1
# CPOY-11AS                     1
# MIP-1AS                       1
# DPOY-1DEF1                    1
# MVP-3CPOY-6ASNBA1             1
# DPOY-10                       1
# CPOY-1ASNBA3                  1
# DPOY-3ASDEF1                  1
# ROY-2                         1
# 6MOY-5                        1
# MVP-4DPOY-9CPOY-12ASNBA1      1
# MVP-2DPOY-7CPOY-3ASNBA1       1
# CPOY-10ASNBA3                 1
# ASNBA2                        1
# DPOY-8DEF2                    1
# ...

# %%
plt.figure(figsize=(12, 6))
plt.bar(awards.index, awards.values)
plt.xlabel('Awards')
plt.yscale('log')
plt.ylabel('Count')
plt.title('Distribution of Awards')
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'Age', 'Team', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%',
#        '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%',
#        'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP',
#        'Awards', 'Player-additional'],
#       dtype='object')

# %%
df=df.drop(columns=['Rk','Player-additional'])

# %%
df.head()
# Out:
#              Player   Age Team Pos     G    GS      MP   PER    TS%   3PAr  \
# 0     DeMar DeRozan  34.0  CHI  SF  79.0  79.0  2989.0  19.7  0.584  0.166
# 1  Domantas Sabonis  27.0  SAC   C  82.0  82.0  2928.0  23.2  0.637  0.081
# 2        Coby White  23.0  CHI  PG  79.0  78.0  2881.0  14.5  0.570  0.460
# 3     Mikal Bridges  27.0  BRK  SF  82.0  82.0  2854.0  14.9  0.560  0.457
# 4    Paolo Banchero  21.0  ORL  PF  80.0  80.0  2799.0  17.3  0.546  0.249
#
#      FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  OWS  DWS    WS  \
# 0  0.452   1.6  11.3   6.4  21.8   1.5   1.5   7.7  25.8  7.0  2.2   9.2
# 1  0.389  11.0  32.3  21.4  33.9   1.2   1.5  17.9  22.2  8.6  4.0  12.6
# 2  0.215   1.7  12.4   6.9  20.8   0.9   0.6  11.1  22.7  3.1  1.6   4.7
# 3  0.245   2.5  12.0   7.1  16.3   1.4   0.9  10.3  24.3  2.1  2.1   4.2
# 4  0.397   3.4  20.0  11.6  25.2   1.3   1.6  13.0  29.7  1.3  4.0   5.3
#
#    WS/48  OBPM  DBPM  BPM  VORP            Awards
# ...

# %%
df.to_csv('new_wnba.csv')
